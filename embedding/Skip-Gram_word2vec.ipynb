# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
text[1:1000]
# Out:
# 'anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or anomie but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic instituti'

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here

from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}

# The final subsampled word list
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    
    if idx - R >0:
        start = idx - R
    else:
        start = 0
        
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    #https://discussions.udacity.com/t/skip-gram-word2vec-solution-get-target/313232
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6231 0.3839 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6269 0.3380 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4673 0.3637 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5974 0.4415 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5139 0.4017 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5335 0.4069 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5611 0.3988 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5444 0.3933 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4713 0.3823 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4397 0.3873 sec/batch
# Nearest to however: frankfurt, coolant, bagley, perennially, assiduously, loader, shiv, tubulin,
# Nearest to it: mosaic, sino, pod, auroral, timetables, emerged, prefect, corporeal,
# Nearest to its: fannie, fricatives, instant, mengistu, catalyse, gyatso, gwynne, pskov,
# Nearest to d: ztas, hybrid, oratorios, covert, homma, resources, invites, riaa,
# Nearest to and: biblia, processional, wotan, heng, inspiring, menhirs, fanu, mindset,
# Nearest to two: quartets, number, landlocked, slept, ldc, rooms, mcmurray, talker,
# Nearest to than: mordecai, worldstatesmen, ajaigarh, ledoux, lazarev, lagonda, selects, influenced,
# Nearest to people: inking, wounds, gop, slava, peacocks, alison, pigeons, plaudits,
# Nearest to quite: falange, composting, government, german, rolls, shem, stoney, kenjutsu,
# Nearest to defense: morphology, digests, naked, counterproductive, goukouni, inward, induces, leveling,
# Nearest to marriage: intermixed, struts, multiplications, nihilo, imperative, arranges, advantage, neon,
# Nearest to ocean: juniors, laboratories, bahini, germanic, sensual, bonnie, monasticism, native,
# Nearest to professional: kitakyushu, vannevar, hond, subsequent, maclennan, hyper, hikari, jardines,
# Nearest to scale: trivially, puritanical, venezuelan, dagobert, gubbio, adornment, vanishes, amyntas,
# Nearest to square: seo, documents, persepolis, gopal, beas, gibraltarian, mentored, logotype,
# Nearest to grand: officio, lapis, developers, corsairs, godf, autocephalous, appropriation, nausea,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4909 0.3915 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3946 0.3821 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3527 0.3828 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2664 0.3813 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2129 0.4546 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2063 0.3850 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0985 0.3873 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0851 0.3826 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0212 0.3379 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9949 0.3404 sec/batch
# Nearest to however: coolant, perennially, frankfurt, martyrs, dioceses, national, interest, it,
# Nearest to it: mosaic, sino, emerged, pod, auroral, send, organizational, number,
# Nearest to its: instant, fricatives, fannie, catalyse, ecological, thickness, mengistu, areas,
# Nearest to d: hybrid, resources, homma, covert, ztas, hammurabi, oratorios, three,
# Nearest to and: biblia, wotan, really, processional, indicated, inspiring, heng, through,
# Nearest to two: number, quartets, landlocked, plains, slept, just, ghent, invaded,
# Nearest to than: humans, worldstatesmen, mordecai, takes, influenced, selects, personal, lost,
# Nearest to people: wounds, seen, inking, slava, proponents, pigeons, emergency, plaudits,
# Nearest to quite: government, german, an, composting, image, falange, firmly, persecuted,
# Nearest to defense: morphology, digests, naked, counterproductive, searches, inward, marguerite, goukouni,
# Nearest to marriage: advantage, arranges, nihilo, customs, separately, intermixed, davis, struts,
# Nearest to ocean: germanic, laboratories, native, application, juniors, sensual, bahini, examination,
# Nearest to professional: kitakyushu, subsequent, hond, vannevar, handled, moreover, hyper, gutenberg,
# Nearest to scale: puritanical, trivially, how, venezuelan, upper, superposition, vanishes, exceptionalism,
# Nearest to square: documents, seo, country, gopal, persepolis, inferred, zones, mentored,
# Nearest to grand: officio, lapis, developers, appropriation, traveling, superseded, corsairs, using,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9242 0.4135 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8981 0.4098 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9007 0.4002 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8790 0.3643 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7999 0.3523 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8338 0.3395 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7930 0.3433 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7782 0.3411 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7893 0.3414 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7577 0.3399 sec/batch
# Nearest to however: frankfurt, perennially, heavier, coolant, bagley, impression, martyrs, dioceses,
# Nearest to it: mosaic, sino, emerged, prefect, pod, organizational, auroral, confrontations,
# Nearest to its: instant, fannie, fricatives, ecological, mengistu, thickness, geometrical, staged,
# Nearest to d: hybrid, ztas, homma, three, oratorios, resources, covert, maid,
# Nearest to and: biblia, troubles, really, processional, wotan, inspiring, heng, exposures,
# Nearest to two: number, landlocked, quartets, slept, rooms, invaded, ghent, plains,
# Nearest to than: worldstatesmen, mordecai, humans, lip, crossed, ajaigarh, influenced, personal,
# Nearest to people: wounds, inking, slava, alison, pigeons, seen, proclaimed, plaudits,
# Nearest to quite: government, falange, german, composting, an, rolls, firmly, achieved,
# Nearest to defense: morphology, digests, naked, inward, searches, counterproductive, viewpoints, scraps,
# Nearest to marriage: arranges, advantage, customs, multiplications, nihilo, neon, davis, imperative,
# Nearest to ocean: germanic, application, contingent, bahini, native, laboratories, behave, juniors,
# Nearest to professional: kitakyushu, subsequent, vannevar, hond, moreover, gutenberg, hyper, destabilize,
# Nearest to scale: puritanical, trivially, venezuelan, vanishes, how, superposition, exceptionalism, crumbling,
# Nearest to square: documents, seo, country, gopal, fortifications, generic, zones, mentored,
# Nearest to grand: officio, developers, lapis, appropriation, corsairs, yale, superseded, autocephalous,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7763 0.3450 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7439 0.3416 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7108 0.3388 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7241 0.3369 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7634 0.3416 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6928 0.3391 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7092 0.3384 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7155 0.3386 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6903 0.3377 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6527 0.3390 sec/batch
# Nearest to however: perennially, heavier, bagley, frankfurt, coolant, dioceses, martyrs, grooves,
# Nearest to it: mosaic, prefect, pod, sino, auroral, emerged, confrontations, organizational,
# Nearest to its: fannie, instant, mengistu, fricatives, querying, ecological, staged, filename,
# Nearest to d: three, homma, ztas, kaufman, six, george, maid, oratorios,
# Nearest to and: biblia, troubles, processional, heng, ensuing, wotan, exposures, peabody,
# Nearest to two: landlocked, three, quartets, number, seven, rooms, slept, ghent,
# Nearest to than: worldstatesmen, seljuk, mordecai, takes, incriminating, humans, hormonal, lip,
# Nearest to people: wounds, inking, pigeons, alison, proclaimed, plaudits, slava, qq,
# Nearest to quite: falange, government, composting, fluency, rolls, shem, zuse, german,
# Nearest to defense: morphology, digests, naked, inward, goukouni, leveling, scraps, excavations,
# Nearest to marriage: multiplications, nchen, customs, arranges, integrals, nihilo, davis, advantage,
# Nearest to ocean: germanic, contingent, native, adorned, application, juniors, vanished, behave,
# Nearest to professional: kitakyushu, subsequent, vannevar, hond, gutenberg, destabilize, ingrained, bards,
# Nearest to scale: puritanical, trivially, vanishes, venezuelan, flogged, exceptionalism, sunspot, crumbling,
# Nearest to square: seo, documents, gopal, country, mentored, zones, fortifications, persepolis,
# Nearest to grand: officio, developers, lapis, yale, appropriation, superseded, corsairs, tier,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6658 0.3392 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6628 0.3376 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6215 0.3411 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6339 0.3411 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6102 0.3387 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6221 0.3385 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5752 0.2532 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5287 0.3454 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5217 0.3429 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4764 0.3400 sec/batch
# Nearest to however: perennially, heavier, bagley, tubulin, coolant, hoppers, retitled, dioceses,
# Nearest to it: mosaic, prefect, auroral, pod, confrontations, emerged, sino, send,
# Nearest to its: fannie, instant, mengistu, fricatives, gyatso, thickness, querying, staged,
# Nearest to d: three, photographer, george, physicist, writer, six, maid, ztas,
# Nearest to and: biblia, processional, heng, peabody, troubles, ensuing, fanu, wotan,
# Nearest to two: three, seven, landlocked, dancer, quartets, one, number, congressman,
# Nearest to than: worldstatesmen, mordecai, hormonal, seljuk, humans, incriminating, oui, cruithne,
# Nearest to people: inking, wounds, pigeons, proclaimed, plaudits, alison, gop, slava,
# Nearest to quite: falange, composting, shem, fluency, rolls, zuse, kenjutsu, government,
# Nearest to defense: digests, morphology, naked, scraps, inward, goukouni, counterproductive, gallipoli,
# Nearest to marriage: hermann, nchen, integrals, multiplications, customs, arranges, valdez, davis,
# Nearest to ocean: germanic, contingent, native, juniors, vanished, lifeform, south, inland,
# Nearest to professional: kitakyushu, vannevar, hond, subsequent, ingrained, gutenberg, destabilize, hikari,
# Nearest to scale: puritanical, trivially, vanishes, exceptionalism, sunspot, superposition, how, franchised,
# Nearest to square: seo, zones, country, gopal, documents, mentored, persepolis, modulated,
# Nearest to grand: officio, lapis, wil, stockwell, yale, developers, isoleucine, corsairs,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5218 0.3446 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4793 0.3390 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4795 0.3388 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5282 0.3387 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5101 0.3382 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4961 0.3379 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4469 0.3403 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3852 0.3376 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4298 0.3361 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4400 0.3376 sec/batch
# Nearest to however: perennially, bagley, heavier, tubulin, grooves, bethlehem, dioceses, hoppers,
# Nearest to it: mosaic, pod, auroral, emerged, send, prefect, confrontations, colored,
# Nearest to its: fannie, instant, fricatives, mengistu, ecological, thickness, gyatso, areas,
# Nearest to d: ztas, photographer, kaufman, homma, blythe, wallace, oratorios, three,
# Nearest to and: biblia, heng, processional, perceives, fanu, troubles, legal, peabody,
# Nearest to two: three, landlocked, number, quartets, seven, unpaved, zero, tunny,
# Nearest to than: worldstatesmen, hormonal, mordecai, cruithne, humans, oui, seljuk, incriminating,
# Nearest to people: inking, pigeons, wounds, gop, proclaimed, plaudits, alison, seen,
# Nearest to quite: composting, falange, shem, fluency, rolls, zuse, kenjutsu, nostradamus,
# Nearest to defense: digests, morphology, gallipoli, expedient, goukouni, naked, scraps, patriae,
# Nearest to marriage: valdez, nchen, multiplications, hermann, integrals, customs, nihilo, arranges,
# Nearest to ocean: south, inland, native, contingent, geographical, lifeform, germanic, geography,
# Nearest to professional: kitakyushu, vannevar, hond, subsequent, ingrained, hikari, gutenberg, wiles,
# Nearest to scale: puritanical, trivially, vanishes, exceptionalism, ay, franchised, superposition, amyntas,
# Nearest to square: zones, country, hilly, gopal, meters, seo, hills, nautical,
# Nearest to grand: officio, wil, lapis, stockwell, yale, eventful, developers, corsairs,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4438 0.3439 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4298 0.3396 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4309 0.3392 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3995 0.3383 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4040 0.3368 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4244 0.3407 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3819 0.3390 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3973 0.3358 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4118 0.3387 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3840 0.3396 sec/batch
# Nearest to however: heavier, perennially, dioceses, bethlehem, democide, bagley, tubulin, permissions,
# Nearest to it: mosaic, emerged, prefect, deteriorates, auroral, send, pod, confrontations,
# Nearest to its: instant, fannie, mengistu, fricatives, thickness, eakins, ecological, ceramics,
# Nearest to d: ztas, homma, blythe, photographer, paolo, three, kaufman, elector,
# Nearest to and: biblia, heng, processional, peabody, troubles, fanu, hague, inspiring,
# Nearest to two: three, seven, number, zero, one, landlocked, lindsay, quartets,
# Nearest to than: worldstatesmen, hormonal, mordecai, seljuk, cruithne, takes, sado, oui,
# Nearest to people: inking, gop, pigeons, wounds, plaudits, proclaimed, alison, seen,
# Nearest to quite: composting, falange, shem, fluency, kenjutsu, rolls, zuse, firmly,
# Nearest to defense: digests, gallipoli, morphology, expedient, scraps, goukouni, patriae, naked,
# Nearest to marriage: valdez, nchen, nihilo, customs, multiplications, hermann, integrals, considers,
# Nearest to ocean: south, inland, native, coordinates, geographical, geography, contingent, rainfall,
# Nearest to professional: kitakyushu, vannevar, hond, ingrained, hikari, wiles, gutenberg, gladius,
# Nearest to scale: trivially, puritanical, vanishes, superposition, sunspot, exceptionalism, ay, composite,
# Nearest to square: hilly, meters, zones, nautical, gopal, fortifications, modulated, hills,
# Nearest to grand: officio, wil, lapis, stockwell, eventful, isoleucine, traveling, developers,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3686 0.3425 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4016 0.3405 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3736 0.3389 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3783 0.3406 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3682 0.3412 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3608 0.3387 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3760 0.3381 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3789 0.3384 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3056 0.3369 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3246 0.3354 sec/batch
# Nearest to however: perennially, antisemitic, democide, buckminsterfullerene, heavier, permissions, tubulin, dioceses,
# Nearest to it: mosaic, prefect, emerged, send, deteriorates, organizational, pod, difficult,
# Nearest to its: fannie, instant, fricatives, mengistu, arrayed, ceramics, thickness, homeowners,
# Nearest to d: ztas, homma, blythe, oratorios, abernathy, hybrid, photographer, paolo,
# Nearest to and: biblia, processional, heng, storied, legal, peabody, tips, leto,
# Nearest to two: three, seven, number, zero, one, landlocked, lindsay, unpaved,
# Nearest to than: hormonal, worldstatesmen, ramming, cruithne, exemptions, mordecai, sado, seljuk,
# Nearest to people: inking, gop, pigeons, proclaimed, plaudits, isaak, peacocks, wounds,
# Nearest to quite: composting, fluency, falange, shem, kenjutsu, zuse, rolls, bonobo,
# Nearest to defense: gallipoli, digests, expedient, goukouni, scraps, patriae, fallacious, gah,
# Nearest to marriage: valdez, customs, nchen, marriages, nihilo, hermann, academia, considers,
# Nearest to ocean: inland, south, wooded, coordinates, geography, rainfall, tropical, geographical,
# Nearest to professional: kitakyushu, vannevar, hond, ingrained, wiles, mcs, hikari, subsequent,
# Nearest to scale: trivially, vanishes, sunspot, franchised, puritanical, exceptionalism, ay, composite,
# Nearest to square: zones, meters, hilly, nautical, modulated, gopal, seo, fortifications,
# Nearest to grand: officio, wil, stockwell, lapis, eventful, godf, proscribed, isoleucine,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3358 0.3428 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2854 0.3431 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3836 0.3405 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3655 0.3376 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4224 0.3375 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2848 0.3378 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3048 0.3330 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3504 0.3375 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2314 0.3364 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3126 0.3405 sec/batch
# Nearest to however: democide, perennially, antisemitic, bethlehem, heavier, buckminsterfullerene, tubulin, dioceses,
# Nearest to it: mosaic, deteriorates, prefect, difficult, emerged, cauchy, circumcision, confrontations,
# Nearest to its: fannie, mengistu, instant, fricatives, homeowners, arrayed, ceramics, gwynne,
# Nearest to d: physicist, paolo, three, ztas, homma, photographer, abernathy, archaeologist,
# Nearest to and: biblia, processional, wotan, peabody, legal, heng, storied, enterprise,
# Nearest to two: three, seven, zero, one, number, five, lindsay, nine,
# Nearest to than: hormonal, worldstatesmen, cruithne, ramming, sado, resale, exemptions, incriminating,
# Nearest to people: inking, plaudits, gop, proclaimed, pigeons, yehuda, isaak, aerodrome,
# Nearest to quite: composting, falange, fluency, shem, bonobo, kenjutsu, gibberish, rolls,
# Nearest to defense: gallipoli, expedient, goukouni, digests, scraps, resigned, patriae, gah,
# Nearest to marriage: valdez, nchen, marriages, customs, academia, considers, intermixed, nihilo,
# Nearest to ocean: inland, coordinates, south, wooded, geography, native, geographical, rainfall,
# Nearest to professional: kitakyushu, vannevar, hond, hikari, brenly, commerzbank, wiles, ingrained,
# Nearest to scale: trivially, composite, puritanical, vanishes, ay, sunspot, franchised, superposition,
# Nearest to square: meters, zones, nautical, hilly, modulated, seo, fortifications, gopal,
# Nearest to grand: officio, wil, lapis, stockwell, eventful, isoleucine, godf, traveling,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3139 0.3446 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2882 0.3372 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3586 0.1572 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2695 0.3374 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2338 0.3382 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2252 0.3396 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2099 0.3380 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2207 0.3385 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2293 0.3393 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1888 0.3383 sec/batch
# Nearest to however: perennially, democide, dioceses, bagley, antisemitic, heavier, curvilinear, bethlehem,
# Nearest to it: mosaic, deteriorates, emerged, circumcision, pod, prefect, sidewalk, deform,
# Nearest to its: instant, fannie, mengistu, fricatives, homeowners, originally, gwynne, densely,
# Nearest to d: ztas, abernathy, three, homma, physicist, paolo, b, elector,
# Nearest to and: biblia, wotan, processional, storied, enterprise, salty, tips, midtown,
# Nearest to two: three, zero, seven, one, number, five, lindsay, unpaved,
# Nearest to than: hormonal, sado, ramming, cruithne, sedating, worldstatesmen, oui, optically,
# Nearest to people: inking, plaudits, pigeons, gop, afro, proclaimed, isaak, yehuda,
# Nearest to quite: composting, falange, fluency, bonobo, shem, kenjutsu, thicknesses, firmly,
# Nearest to defense: gallipoli, expedient, digests, patriae, goukouni, scraps, pro, resigned,
# Nearest to marriage: valdez, marriages, customs, nchen, considers, attainder, moldings, redford,
# Nearest to ocean: coordinates, south, wooded, inland, geographical, native, atlantic, geography,
# Nearest to professional: kitakyushu, vannevar, hond, brenly, mcs, hikari, ingrained, wiles,
# Nearest to scale: ay, composite, puritanical, trivially, sunspot, refraction, exceptionalism, flogged,
# Nearest to square: hilly, nautical, meters, zones, fortifications, pickers, gopal, discontinuous,
# Nearest to grand: officio, wil, lapis, stockwell, eventful, godf, traveling, isoleucine,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2185 0.3442 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2230 0.3373 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2258 0.3359 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1120 0.3359 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1795 0.3378 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1783 0.3353 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1605 0.3336 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1940 0.3377 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1849 0.3381 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1844 0.3387 sec/batch
# Nearest to however: democide, perennially, tubulin, buckminsterfullerene, heavier, bagley, hoppers, degrade,
# Nearest to it: mosaic, deteriorates, circumcision, cauchy, infants, difficult, sidewalk, pod,
# Nearest to its: instant, fannie, mengistu, fricatives, arrayed, gwynne, homeowners, originally,
# Nearest to d: ztas, abernathy, homma, hybrid, three, oratorios, des, elector,
# Nearest to and: biblia, storied, heng, inclusions, wotan, tips, processional, menhirs,
# Nearest to two: three, zero, seven, one, number, five, lindsay, unpaved,
# Nearest to than: hormonal, sado, ramming, cruithne, optically, sedating, plated, oui,
# Nearest to people: inking, plaudits, pigeons, gop, isaak, proponents, afro, yehuda,
# Nearest to quite: composting, falange, bonobo, fluency, thicknesses, kenjutsu, shem, firmly,
# Nearest to defense: gallipoli, expedient, pro, scraps, goukouni, resigned, patriae, war,
# Nearest to marriage: marriages, valdez, nihilo, nchen, considers, customs, academia, redford,
# Nearest to ocean: coordinates, inland, geographical, wooded, south, atlantic, contingent, geography,
# Nearest to professional: kitakyushu, vannevar, hond, brenly, mcs, ingrained, hikari, gladius,
# Nearest to scale: ay, composite, trivially, exceptionalism, puritanical, refraction, sunspot, adornment,
# Nearest to square: hilly, meters, discontinuous, zones, gopal, modulated, fortifications, pickers,
# Nearest to grand: officio, wil, lapis, eventful, isoleucine, godf, stockwell, peregrine,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1779 0.3445 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2240 0.3349 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1629 0.3405 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1745 0.3373 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1910 0.3358 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1703 0.3382 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2034 0.3379 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1690 0.3351 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1260 0.3375 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2017 0.3392 sec/batch
# Nearest to however: democide, perennially, tubulin, buckminsterfullerene, heavier, fundamentalist, hoppers, dioceses,
# Nearest to it: mosaic, deteriorates, send, pod, emerged, difficult, circumcision, cauchy,
# Nearest to its: instant, fricatives, fannie, mengistu, homeowners, filename, originally, filking,
# Nearest to d: ztas, abernathy, homma, three, des, b, elector, physicist,
# Nearest to and: biblia, heng, dw, storied, colloquialism, enterprise, situs, wotan,
# Nearest to two: three, zero, seven, one, five, number, nine, lindsay,
# Nearest to than: hormonal, sado, ramming, optically, cruithne, sedating, resale, incriminating,
# Nearest to people: inking, plaudits, afro, pigeons, proponents, aerodrome, gop, elo,
# Nearest to quite: composting, fluency, shem, kenjutsu, falange, bonobo, thicknesses, firmly,
# Nearest to defense: gallipoli, expedient, goukouni, resigned, patriae, oversees, scraps, jima,
# Nearest to marriage: marriages, nchen, attainder, customs, academia, nihilo, voltaire, intermixed,
# Nearest to ocean: inland, coordinates, geographical, atlantic, wooded, south, geography, freshwater,
# Nearest to professional: kitakyushu, vannevar, hond, brenly, ingrained, wiles, hikari, mcs,
# Nearest to scale: ay, composite, refraction, trivially, adornment, superposition, sunspot, exceptionalism,
# Nearest to square: hilly, modulated, seo, gopal, discontinuous, meters, como, pickers,
# Nearest to grand: officio, wil, leyland, lapis, eventful, isoleucine, bardeen, godf,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1951 0.3432 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1853 0.3411 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1844 0.3377 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1754 0.3378 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1331 0.3385 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1338 0.3360 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1735 0.3379 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1366 0.3403 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1734 0.3394 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2312 0.3396 sec/batch
# Nearest to however: perennially, democide, hanja, tubulin, dioceses, clouded, fundamentalist, hubs,
# Nearest to it: mosaic, send, deteriorates, menai, opencores, prefect, sino, emerged,
# Nearest to its: instant, mengistu, fannie, homeowners, filking, delano, codified, gyatso,
# Nearest to d: ztas, b, three, homma, archaeologist, oratorios, abernathy, physicist,
# Nearest to and: biblia, of, the, retainers, heng, detain, unaccountable, seleucid,
# Nearest to two: three, zero, one, seven, five, nine, number, lindsay,
# Nearest to than: sado, hormonal, ramming, incriminating, takes, reichsf, gaspra, resale,
# Nearest to people: inking, plaudits, aerodrome, isaak, yehuda, proponents, seen, pigeons,
# Nearest to quite: composting, bonobo, fluency, kenjutsu, thicknesses, shem, falange, firmly,
# Nearest to defense: expedient, gallipoli, goukouni, resigned, scraps, oversees, patriae, pro,
# Nearest to marriage: attainder, academia, nchen, marriages, moldings, intermixed, ambassadorial, customs,
# Nearest to ocean: coordinates, inland, atlantic, wooded, lope, contingent, vanished, geographical,
# Nearest to professional: kitakyushu, vannevar, hond, brenly, mcs, wiles, ingrained, sports,
# Nearest to scale: ay, adornment, refraction, sunspot, flogged, trivially, composite, exceptionalism,
# Nearest to square: gopal, seo, fortifications, hilly, como, fjord, modulated, discontinuous,
# Nearest to grand: officio, wil, leyland, lapis, eventful, joss, adolphus, godf,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2252 0.3431 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1348 0.3403 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1208 0.3343 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1389 0.3365 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0538 0.3378 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1282 0.3391 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1265 0.3374 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1316 0.3377 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1853 0.0648 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1256 0.3399 sec/batch
# Nearest to however: perennially, democide, hanja, tubulin, fundamentalist, buckminsterfullerene, dioceses, cloned,
# Nearest to it: mosaic, deteriorates, send, menai, deform, chance, inserting, cauchy,
# Nearest to its: instant, gwynne, homeowners, mengistu, routed, filename, filking, fannie,
# Nearest to d: ztas, three, abernathy, homma, b, physicist, oratorios, archaeologist,
# Nearest to and: biblia, of, the, enterprise, colloquialism, dw, heng, belgaum,
# Nearest to two: three, zero, seven, one, five, nine, number, six,
# Nearest to than: hormonal, sado, ramming, optically, takes, resale, throughput, reichsf,
# Nearest to people: inking, plaudits, aerodrome, afro, elo, seen, isaak, peacefully,
# Nearest to quite: bonobo, kenjutsu, composting, thicknesses, fluency, falange, centrist, reflectivity,
# Nearest to defense: expedient, gallipoli, pro, scraps, patriae, goukouni, resigned, quarterback,
# Nearest to marriage: marriages, attainder, moldings, intermixed, customs, academia, ambassadorial, bujold,
# Nearest to ocean: atlantic, inland, coordinates, vanished, lope, contingent, geographical, freshwater,
# Nearest to professional: kitakyushu, vannevar, hond, brenly, mcs, sports, trax, hikari,
# Nearest to scale: refraction, ay, composite, adornment, trivially, flogged, superposition, sunspot,
# Nearest to square: como, gopal, hilly, seo, nearby, fortifications, discontinuous, pickers,
# Nearest to grand: officio, wil, leyland, eventful, adolphus, zadar, bardeen, lapis,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0672 0.3443 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0772 0.3399 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0665 0.3384 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0529 0.3392 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0900 0.3391 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0132 0.3391 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1144 0.3381 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0931 0.3387 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1290 0.3392 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0237 0.3383 sec/batch
# Nearest to however: democide, perennially, tubulin, because, hanja, procedure, fundamentalist, curvilinear,
# Nearest to it: mosaic, deteriorates, send, menai, difficult, propels, sidewalk, not,
# Nearest to its: instant, homeowners, originally, fannie, densely, kirchenmusik, routed, north,
# Nearest to d: ztas, abernathy, homma, oratorios, ntoskrnl, archaeologist, elector, b,
# Nearest to and: biblia, belgaum, the, of, storied, boomed, wotan, enterprise,
# Nearest to two: three, zero, seven, one, five, nine, number, four,
# Nearest to than: hormonal, ramming, sado, reichsf, sedating, takes, thousand, incriminating,
# Nearest to people: inking, afro, plaudits, seen, aerodrome, elo, population, proponents,
# Nearest to quite: bonobo, composting, kenjutsu, thicknesses, reflectivity, falange, firmly, fluency,
# Nearest to defense: expedient, gallipoli, fallacious, scraps, pro, jima, quarterback, resigned,
# Nearest to marriage: attainder, ambassadorial, marriages, intermixed, customs, moldings, academia, redford,
# Nearest to ocean: atlantic, coordinates, inland, vanished, lope, contingent, south, geographical,
# Nearest to professional: kitakyushu, vannevar, trax, brenly, ingrained, hond, wiles, postures,
# Nearest to scale: ay, refraction, adornment, flogged, puritanical, catolica, composite, nieve,
# Nearest to square: nearby, gopal, hilly, como, discontinuous, fortifications, pickers, which,
# Nearest to grand: officio, wil, leyland, eventful, adolphus, lapis, joss, zadar,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0175 0.3462 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0347 0.3357 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0236 0.3360 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0507 0.3373 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0812 0.3407 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0552 0.3362 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0551 0.3370 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0890 0.3187 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0446 0.3382 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0379 0.3379 sec/batch
# Nearest to however: democide, hanja, tubulin, because, clouded, counterexamples, driving, fundamentalist,
# Nearest to it: mosaic, deteriorates, not, menai, difficult, deform, hammers, send,
# Nearest to its: instant, bivalence, homeowners, routed, originally, fannie, arrayed, kirchenmusik,
# Nearest to d: ztas, abernathy, homma, ntoskrnl, three, hybrid, oratorios, b,
# Nearest to and: biblia, belgaum, of, the, dw, storied, spike, situs,
# Nearest to two: zero, three, one, seven, five, nine, four, number,
# Nearest to than: hormonal, sado, ramming, sedating, throughput, optically, capita, reichsf,
# Nearest to people: inking, plaudits, proponents, afro, elo, isaak, aerodrome, population,
# Nearest to quite: bonobo, composting, kenjutsu, thicknesses, reflectivity, firmly, shem, falange,
# Nearest to defense: expedient, scraps, fallacious, quarterback, gallipoli, patriae, pro, goukouni,
# Nearest to marriage: marriages, ambassadorial, customs, moldings, intermixed, attainder, voltaire, academia,
# Nearest to ocean: atlantic, inland, coordinates, lope, chagos, vanished, freshwater, contingent,
# Nearest to professional: kitakyushu, vannevar, ingrained, trax, postures, brenly, hond, wiles,
# Nearest to scale: refraction, ay, adornment, composite, trivially, sunspot, nieve, flogged,
# Nearest to square: hilly, discontinuous, which, gopal, pickers, seo, nearby, como,
# Nearest to grand: officio, wil, leyland, zadar, adolphus, joss, eventful, nyu,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0518 0.3420 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1059 0.3389 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0653 0.3372 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0419 0.3356 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0608 0.3384 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0488 0.3411 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0549 0.3366 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0671 0.3387 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0888 0.3396 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0845 0.3380 sec/batch
# Nearest to however: hanja, democide, heavier, perennially, because, cloned, ruhr, dioceses,
# Nearest to it: mosaic, menai, not, deteriorates, send, requiring, clone, no,
# Nearest to its: routed, homeowners, instant, filking, bivalence, fannie, originally, neighboring,
# Nearest to d: ztas, homma, abernathy, oratorios, ntoskrnl, hybrid, elector, b,
# Nearest to and: of, the, seleucid, biblia, belgaum, part, ensuing, dw,
# Nearest to two: three, zero, one, seven, five, nine, four, six,
# Nearest to than: hormonal, ramming, sado, thousand, capita, reichsf, sedating, immediate,
# Nearest to people: inking, afro, plaudits, population, elo, peacocks, patois, peacefully,
# Nearest to quite: bonobo, composting, kenjutsu, falange, fluency, reflectivity, shem, thicknesses,
# Nearest to defense: expedient, scraps, transportation, patriae, goukouni, fallacious, gallipoli, jima,
# Nearest to marriage: marriages, intermixed, ambassadorial, moldings, customs, attainder, marry, motherhood,
# Nearest to ocean: atlantic, inland, lope, coordinates, chagos, vanished, contingent, wooded,
# Nearest to professional: kitakyushu, vannevar, trax, ingrained, postures, hond, mcs, brenly,
# Nearest to scale: nieve, refraction, ay, venezuelan, adornment, flogged, trivially, puritanical,
# Nearest to square: which, gopal, como, discontinuous, seo, nearby, modulated, hilly,
# Nearest to grand: officio, wil, leyland, zadar, adolphus, nyu, bardeen, joss,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0719 0.3447 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0205 0.3370 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0446 0.3366 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0594 0.3387 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0606 0.3413 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1217 0.3392 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1231 0.3380 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0153 0.3397 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0166 0.3394 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0450 0.3346 sec/batch
# Nearest to however: because, hanja, ruhr, perennially, democide, heavier, cloned, clouded,
# Nearest to it: not, deteriorates, send, inserting, mosaic, requiring, corporeal, menai,
# Nearest to its: instant, homeowners, routed, filking, neighboring, kirchenmusik, fannie, as,
# Nearest to d: homma, ztas, oratorios, abernathy, ntoskrnl, rodger, archaeologist, hybrid,
# Nearest to and: of, the, biblia, belgaum, ensuing, storied, part, enterprise,
# Nearest to two: three, zero, one, seven, five, nine, four, six,
# Nearest to than: hormonal, throughput, capita, sado, thousand, reichsf, sedating, ramming,
# Nearest to people: inking, afro, population, elo, peacefully, plaudits, leptis, isaak,
# Nearest to quite: bonobo, composting, kenjutsu, reflectivity, fluency, falange, thicknesses, firmly,
# Nearest to defense: expedient, scraps, patriae, fallacious, goukouni, pro, gallipoli, organizational,
# Nearest to marriage: ambassadorial, marriages, intermixed, moldings, attainder, marry, motherhood, customs,
# Nearest to ocean: atlantic, inland, lope, chagos, vanished, coordinates, contingent, freshwater,
# Nearest to professional: kitakyushu, vannevar, trax, postures, ingrained, brenly, wiles, mcs,
# Nearest to scale: refraction, nieve, adornment, flogged, puritanical, trivially, ay, sunspot,
# Nearest to square: which, gopal, discontinuous, como, fortifications, icbms, nearby, seo,
# Nearest to grand: officio, wil, leyland, zadar, adolphus, reims, joss, ancestress,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0219 0.3434 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0240 0.3388 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0488 0.3410 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0358 0.3372 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0751 0.3391 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0504 0.3122 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0248 0.3403 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9783 0.3407 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0210 0.3406 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9740 0.3409 sec/batch
# Nearest to however: hanja, because, democide, fundamentalist, cloned, ruhr, perennially, uman,
# Nearest to it: not, mosaic, deteriorates, send, clone, phaistos, waited, gyroelongated,
# Nearest to its: instant, routed, homeowners, gwynne, originally, menger, filename, filking,
# Nearest to d: three, b, abernathy, ztas, homma, archaeologist, oratorios, elector,
# Nearest to and: of, the, crash, storied, biblia, agassi, belgaum, part,
# Nearest to two: three, zero, one, seven, nine, five, four, six,
# Nearest to than: hormonal, thousand, immediate, reichsf, sado, throughput, sedating, ramming,
# Nearest to people: inking, afro, population, elo, plaudits, peacefully, leptis, tailors,
# Nearest to quite: bonobo, reflectivity, composting, kenjutsu, thicknesses, falange, fluency, shem,
# Nearest to defense: expedient, scraps, patriae, fallacious, quarterback, goukouni, transportation, pro,
# Nearest to marriage: marriages, ambassadorial, marry, intermixed, moldings, attainder, customs, motherhood,
# Nearest to ocean: atlantic, chagos, inland, lope, coordinates, contingent, vanished, submarine,
# Nearest to professional: kitakyushu, vannevar, trax, postures, brenly, ingrained, mcs, hond,
# Nearest to scale: refraction, scales, ay, adornment, nieve, puritanical, catolica, gubbio,
# Nearest to square: como, nearby, gopal, which, fortifications, discontinuous, cottage, ith,
# Nearest to grand: officio, wil, leyland, adolphus, zadar, nyu, reims, ancestress,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9970 0.3443 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9413 0.3388 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0080 0.3346 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0117 0.3399 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9921 0.3387 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0002 0.3373 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9483 0.3403 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9357 0.3386 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9306 0.3366 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9922 0.3357 sec/batch
# Nearest to however: because, hanja, heavier, loader, democide, driving, degrade, clouded,
# Nearest to it: deteriorates, not, catchment, mosaic, hammers, sidewalk, is, sunburn,
# Nearest to its: instant, homeowners, routed, menger, originally, buff, gwynne, filking,
# Nearest to d: ztas, homma, hybrid, abernathy, ntoskrnl, oratorios, elector, three,
# Nearest to and: of, the, storied, belgaum, situs, boomed, to, with,
# Nearest to two: three, zero, one, seven, five, nine, four, six,
# Nearest to than: hormonal, sedating, thousand, immediate, takes, reichsf, throughput, ramming,
# Nearest to people: population, inking, afro, leptis, peacefully, plaudits, births, elo,
# Nearest to quite: bonobo, kenjutsu, composting, fluency, reflectivity, falange, thicknesses, firmly,
# Nearest to defense: expedient, quarterback, transportation, scraps, goukouni, patriae, straight, jima,
# Nearest to marriage: marriages, marry, ambassadorial, intermixed, moldings, voltaire, attainder, customs,
# Nearest to ocean: atlantic, inland, chagos, lope, contingent, mariner, vanished, coordinates,
# Nearest to professional: kitakyushu, vannevar, trax, postures, ingrained, brenly, hond, others,
# Nearest to scale: refraction, scales, venezuelan, adornment, puritanical, ay, gubbio, nieve,
# Nearest to square: which, nearby, fortifications, como, gopal, cottage, discontinuous, shopping,
# Nearest to grand: officio, wil, leyland, zadar, adolphus, nyu, ancestress, bardeen,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9825 0.3459 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9776 0.3368 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9779 0.3383 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0182 0.3351 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0647 0.3363 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9579 0.3384 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0148 0.3371 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9971 0.3374 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0009 0.3392 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9965 0.3367 sec/batch
# Nearest to however: because, hanja, heavier, loader, driving, ign, ruhr, determinative,
# Nearest to it: not, deteriorates, natively, inserting, requiring, is, hammers, send,
# Nearest to its: instant, homeowners, the, menger, routed, gwynne, as, to,
# Nearest to d: b, three, abernathy, homma, ztas, archaeologist, tiberian, rodger,
# Nearest to and: the, of, to, dw, storied, part, with, crash,
# Nearest to two: zero, three, one, seven, nine, five, four, six,
# Nearest to than: hormonal, sedating, thousand, sado, ramming, capita, reichsf, throughput,
# Nearest to people: inking, afro, population, elo, leptis, peacefully, plaudits, salamanders,
# Nearest to quite: bonobo, kenjutsu, fluency, reflectivity, composting, falange, thicknesses, firmly,
# Nearest to defense: expedient, scraps, transportation, goukouni, patriae, fallacious, yemenite, quarterback,
# Nearest to marriage: marriages, ambassadorial, marry, intermixed, moldings, customs, voltaire, attainder,
# Nearest to ocean: atlantic, chagos, mariner, contingent, submarine, inland, coordinates, lope,
# Nearest to professional: kitakyushu, vannevar, trax, postures, brenly, ingrained, associations, hond,
# Nearest to scale: refraction, nieve, scales, venezuelan, adornment, ay, gubbio, puritanical,
# Nearest to square: which, como, gopal, ith, fortifications, modulated, cottage, seo,
# Nearest to grand: officio, wil, leyland, zadar, ancestress, nyu, adolphus, bardeen,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9756 0.3443 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9770 0.3388 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9743 0.3371 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0230 0.3372 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0332 0.3392 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0113 0.3396 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9684 0.3373 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9562 0.3383 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9616 0.3358 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0248 0.3397 sec/batch
# Nearest to however: because, hanja, cloned, heavier, it, have, would, was,
# Nearest to it: not, send, deteriorates, clone, had, requiring, menai, no,
# Nearest to its: the, instant, routed, and, homeowners, became, as, menger,
# Nearest to d: homma, b, abernathy, ztas, elector, archaeologist, tiberian, reger,
# Nearest to and: the, of, to, with, part, its, in, their,
# Nearest to two: three, zero, one, seven, nine, five, four, six,
# Nearest to than: hormonal, thousand, immediate, incriminating, ramming, substantially, reichsf, takes,
# Nearest to people: population, inking, afro, births, peacefully, elo, leptis, plaudits,
# Nearest to quite: bonobo, kenjutsu, fluency, reflectivity, composting, thicknesses, falange, differently,
# Nearest to defense: expedient, scraps, yemenite, patriae, goukouni, transportation, fallacious, oversees,
# Nearest to marriage: marriages, marry, ambassadorial, intermixed, moldings, divorce, customs, motherhood,
# Nearest to ocean: atlantic, chagos, mariner, submarine, vanished, contingent, inland, lope,
# Nearest to professional: kitakyushu, postures, trax, vannevar, brenly, ingrained, associations, hond,
# Nearest to scale: scales, venezuelan, bankruptcy, puritanical, nieve, gubbio, vincendeau, refraction,
# Nearest to square: como, gopal, ith, which, nearby, cottage, fortifications, dion,
# ...
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8728 0.3361 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9107 0.3374 sec/batch
# Nearest to however: because, which, it, but, have, not, would, kubrick,
# Nearest to it: not, that, is, but, to, a, which, in,
# Nearest to its: the, an, and, as, which, is, to, in,
# Nearest to d: b, covert, hybrid, seals, parrots, mnp, three, marchese,
# Nearest to and: the, of, in, as, with, to, also, a,
# Nearest to two: three, zero, one, nine, four, seven, five, six,
# Nearest to than: immediate, greater, less, are, more, substantially, is, thousand,
# Nearest to people: births, living, actors, deaths, leptis, their, items, population,
# Nearest to quite: bonobo, updates, kenjutsu, able, extremely, composting, fluency, more,
# Nearest to defense: expedient, strategic, transportation, yemenite, quarterback, perseverance, icbms, linebackers,
# Nearest to marriage: marriages, marry, divorce, ambassadorial, unmarried, spouse, married, intermixed,
# Nearest to ocean: atlantic, fermium, seafloor, landmasses, mariner, chagos, caste, vanished,
# Nearest to professional: kitakyushu, postures, associations, ingrained, teachers, formalised, vannevar, trax,
# Nearest to scale: scales, bankruptcy, psychometrics, vincendeau, adorned, clockmaker, entrepreneurs, monopolies,
# Nearest to square: rectification, chalcolithic, ith, fortifications, como, kilometer, depicts, pickers,
# Nearest to grand: officio, leyland, prix, wil, ancestress, anesthetic, loi, se,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8274 0.3444 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8519 0.3371 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8758 0.3371 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8577 0.3383 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8445 0.3370 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8625 0.3375 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8512 0.3396 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8251 0.3365 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8964 0.3377 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8516 0.3411 sec/batch
# Nearest to however: because, which, but, the, have, to, it, would,
# Nearest to it: not, that, is, but, to, put, which, its,
# Nearest to its: the, an, and, as, in, to, is, which,
# Nearest to d: b, covert, hybrid, undoubtedly, mnp, parrots, seals, rodger,
# Nearest to and: of, the, in, as, with, to, also, a,
# Nearest to two: three, zero, one, nine, seven, five, four, six,
# Nearest to than: thousand, immediate, less, greater, is, more, are, substantially,
# Nearest to people: births, living, leptis, actors, their, items, deaths, see,
# Nearest to quite: bonobo, able, extremely, fluency, composting, kenjutsu, updates, falange,
# Nearest to defense: strategic, expedient, yemenite, transportation, perseverance, icbms, quarterback, briefing,
# Nearest to marriage: marriages, divorce, marry, ambassadorial, unmarried, spouse, intermixed, married,
# Nearest to ocean: atlantic, fermium, seafloor, submarine, mariner, chagos, landmasses, caste,
# Nearest to professional: kitakyushu, postures, associations, teachers, formalised, vannevar, ingrained, childish,
# Nearest to scale: scales, bankruptcy, psychometrics, vincendeau, refraction, zubr, adorned, clockmaker,
# Nearest to square: rectification, chalcolithic, ith, fortifications, como, kilometer, depicts, frits,
# Nearest to grand: officio, prix, leyland, wil, ancestress, anesthetic, se, loi,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8703 0.3458 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8736 0.3374 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8136 0.3384 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8709 0.3365 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8833 0.3397 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8393 0.3408 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9495 0.3400 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8909 0.3395 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9208 0.3378 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8071 0.3385 sec/batch
# Nearest to however: because, have, which, to, it, although, survived, but,
# Nearest to it: not, that, is, to, have, which, but, put,
# Nearest to its: the, and, an, as, to, in, which, is,
# Nearest to d: b, undoubtedly, parrots, covert, archaeologist, mnp, rodger, hybrid,
# Nearest to and: of, the, in, with, as, to, a, also,
# Nearest to two: three, zero, one, nine, four, seven, five, six,
# Nearest to than: less, immediate, thousand, more, greater, substantially, are, hormonal,
# Nearest to people: births, living, their, leptis, see, kobe, actors, deaths,
# Nearest to quite: bonobo, fluency, able, extremely, composting, kenjutsu, updates, falange,
# Nearest to defense: expedient, strategic, yemenite, transportation, perseverance, briefing, procurator, icbms,
# Nearest to marriage: marriages, divorce, marry, ambassadorial, unmarried, married, spouse, intermixed,
# Nearest to ocean: atlantic, fermium, mariner, seafloor, caste, arabsat, quito, submarine,
# Nearest to professional: kitakyushu, postures, associations, vannevar, formalised, teachers, ingrained, gifted,
# Nearest to scale: scales, bankruptcy, psychometrics, vincendeau, refraction, clockmaker, adorned, zubr,
# Nearest to square: rectification, ith, como, kilometer, fortifications, chalcolithic, depicts, country,
# Nearest to grand: officio, leyland, ancestress, wil, anesthetic, prix, se, loi,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7960 0.3427 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8714 0.3376 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7976 0.3391 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8630 0.3389 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8596 0.3353 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8566 0.3375 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8669 0.1925 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8169 0.3393 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8318 0.3397 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8624 0.3407 sec/batch
# Nearest to however: because, which, have, but, it, survived, would, not,
# Nearest to it: not, that, to, which, is, put, but, in,
# Nearest to its: the, and, an, as, in, which, to, it,
# Nearest to d: b, william, three, undoubtedly, parrots, six, one, american,
# Nearest to and: of, the, in, to, as, a, with, also,
# Nearest to two: three, zero, one, nine, four, seven, five, six,
# Nearest to than: immediate, less, more, are, greater, thousand, substantially, annually,
# Nearest to people: births, living, leptis, kobe, deaths, their, click, peacefully,
# Nearest to quite: bonobo, composting, able, updates, fluency, falange, officialdom, extremely,
# Nearest to defense: expedient, strategic, yemenite, transportation, quarterback, perseverance, defensive, icbms,
# Nearest to marriage: marriages, divorce, marry, unmarried, ambassadorial, married, spouse, consenting,
# Nearest to ocean: atlantic, mariner, seafloor, fermium, erosive, landmasses, caste, quito,
# Nearest to professional: kitakyushu, postures, associations, vannevar, childish, formalised, teachers, trax,
# Nearest to scale: scales, bankruptcy, psychometrics, vincendeau, zubr, refraction, adorned, transposed,
# Nearest to square: rectification, chalcolithic, ith, kilometer, como, fortifications, depicts, cottage,
# Nearest to grand: leyland, ancestress, prix, wil, officio, anesthetic, se, loi,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8139 0.3465 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8164 0.3388 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8281 0.3394 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7721 0.3383 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8486 0.3399 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8291 0.3391 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8483 0.3365 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7508 0.3391 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8271 0.3380 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7844 0.3390 sec/batch
# Nearest to however: to, which, because, the, have, would, but, it,
# Nearest to it: not, that, but, is, which, to, put, have,
# Nearest to its: the, and, an, as, which, in, to, is,
# Nearest to d: undoubtedly, parrots, b, hybrid, covert, mnp, seals, gg,
# Nearest to and: of, the, in, to, as, other, also, with,
# Nearest to two: three, zero, one, four, nine, seven, five, six,
# Nearest to than: are, less, is, more, thousand, also, immediate, two,
# Nearest to people: births, living, leptis, see, deaths, items, kobe, click,
# Nearest to quite: bonobo, fluency, composting, updates, extremely, officialdom, able, more,
# Nearest to defense: strategic, expedient, transportation, yemenite, perseverance, icbms, defensive, quarterback,
# Nearest to marriage: marriages, divorce, marry, unmarried, ambassadorial, married, spouse, consenting,
# Nearest to ocean: atlantic, mariner, seafloor, fermium, erosive, caste, submarine, sank,
# Nearest to professional: kitakyushu, postures, associations, vannevar, formalised, teachers, childish, netlist,
# Nearest to scale: scales, bankruptcy, psychometrics, vincendeau, zubr, prison, adorned, refraction,
# Nearest to square: rectification, chalcolithic, kilometer, ith, fortifications, depicts, como, country,
# Nearest to grand: leyland, ancestress, prix, officio, wil, anesthetic, se, loi,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7710 0.3429 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8164 0.3396 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8620 0.3403 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8603 0.3367 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8108 0.3364 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9282 0.3374 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8320 0.3384 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8420 0.3358 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8316 0.3383 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8352 0.3397 sec/batch
# Nearest to however: which, it, to, because, but, would, made, the,
# Nearest to it: not, that, but, is, to, the, which, a,
# Nearest to its: the, an, as, and, which, to, in, is,
# Nearest to d: b, undoubtedly, parrots, covert, hybrid, mommu, william, mnp,
# Nearest to and: of, the, in, with, to, as, also, a,
# Nearest to two: three, zero, one, nine, seven, four, five, six,
# Nearest to than: less, are, more, is, immediate, thousand, greater, substantially,
# Nearest to people: births, living, leptis, click, items, see, deaths, their,
# Nearest to quite: bonobo, fluency, extremely, able, officialdom, kenjutsu, composting, falange,
# Nearest to defense: strategic, expedient, transportation, perseverance, yemenite, icbms, briefing, quarterback,
# Nearest to marriage: marriages, divorce, marry, unmarried, married, ambassadorial, spouse, consenting,
# Nearest to ocean: atlantic, fermium, seafloor, mariner, erosive, submarine, quito, biot,
# Nearest to professional: kitakyushu, postures, vannevar, associations, childish, teachers, lips, formalised,
# Nearest to scale: scales, bankruptcy, vincendeau, psychometrics, adorned, zubr, refraction, prison,
# Nearest to square: rectification, ith, chalcolithic, kilometer, fortifications, como, depicts, gopal,
# Nearest to grand: leyland, prix, ancestress, officio, wil, se, loi, anesthetic,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8628 0.3451 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8630 0.3375 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7850 0.3405 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8369 0.3369 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8896 0.3367 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8184 0.3439 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8348 0.3367 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8512 0.3373 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7970 0.3388 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8411 0.3364 sec/batch
# Nearest to however: it, to, have, which, because, the, but, not,
# Nearest to it: not, but, that, to, is, which, a, the,
# Nearest to its: the, an, and, as, in, to, which, it,
# Nearest to d: undoubtedly, hybrid, covert, b, parrots, mnp, mommu, gg,
# Nearest to and: of, the, in, to, with, as, also, on,
# Nearest to two: three, zero, one, nine, four, seven, five, six,
# Nearest to than: less, are, is, more, thousand, immediate, one, substantially,
# Nearest to people: births, living, see, deaths, leptis, their, population, items,
# Nearest to quite: bonobo, falange, extremely, composting, fluency, able, kenjutsu, amusing,
# Nearest to defense: strategic, expedient, transportation, perseverance, yemenite, icbms, correlatives, weapons,
# Nearest to marriage: marriages, divorce, marry, unmarried, ambassadorial, spouse, married, customs,
# Nearest to ocean: atlantic, fermium, submarine, mariner, seafloor, arabsat, erosive, caste,
# Nearest to professional: kitakyushu, postures, associations, vannevar, childish, lips, netlist, trax,
# Nearest to scale: scales, bankruptcy, psychometrics, vincendeau, adorned, prison, clockmaker, refraction,
# Nearest to square: rectification, ith, fortifications, chalcolithic, kilometer, icbms, como, depicts,
# Nearest to grand: leyland, officio, ancestress, prix, se, wil, loi, anesthetic,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8745 0.3438 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8256 0.3408 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9089 0.3384 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9164 0.3406 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8953 0.3347 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8544 0.3394 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7879 0.3344 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8596 0.3350 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7240 0.3393 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8932 0.3403 sec/batch
# Nearest to however: because, which, it, not, have, although, but, would,
# Nearest to it: not, that, but, is, a, to, which, another,
# Nearest to its: the, an, and, in, which, to, as, is,
# Nearest to d: b, william, undoubtedly, one, american, archaeologist, reger, three,
# Nearest to and: of, the, in, with, as, also, a, to,
# Nearest to two: three, zero, one, nine, four, seven, five, six,
# Nearest to than: less, are, immediate, more, thousand, greater, is, annually,
# Nearest to people: living, births, leptis, their, kobe, deaths, see, click,
# Nearest to quite: bonobo, extremely, able, composting, falange, updates, amusing, officialdom,
# Nearest to defense: strategic, expedient, perseverance, transportation, yemenite, icbms, correlatives, micelle,
# Nearest to marriage: marriages, divorce, marry, unmarried, married, ambassadorial, spouse, intermixed,
# Nearest to ocean: atlantic, mariner, fermium, submarine, arabsat, seafloor, caste, dt,
# Nearest to professional: kitakyushu, postures, vannevar, associations, lips, childish, wrestler, trax,
# Nearest to scale: scales, bankruptcy, psychometrics, refraction, vincendeau, clockmaker, zubr, adorned,
# Nearest to square: rectification, kilometer, ith, fortifications, wis, icbms, country, chalcolithic,
# Nearest to grand: leyland, ancestress, prix, officio, se, wil, loi, anesthetic,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8357 0.3435 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8022 0.3368 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
